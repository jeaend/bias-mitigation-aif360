# %% [markdown]
# ## Exploration of base dataset - Compas

# %%
import pandas as pd
import numpy as np
from pathlib import Path
from IPython.display import display

# %%
COMPAS_PATH = Path("/opt/anaconda3/lib/python3.11/site-packages/aif360/data/raw/compas/compas-scores-two-years.csv")
df = pd.read_csv(COMPAS_PATH)

# %%
pd.set_option('display.max_colwidth', None)
top_n = 5
rows = []
for col in df.columns:
    feature_label = 'Target: two_year_recid' if col == 'two_year_recid' else col
    ser = df[col]

    if pd.api.types.is_numeric_dtype(ser):
        rows.append({
            'Feature': feature_label,
            'Type': 'Continuous',
            'Min': ser.min(),
            'Max': ser.max(),
            'Mean': round(ser.mean(), 2),
            'Std': round(ser.std(), 2),
            'Values': ''
        })
    else:
        counts = ser.dropna().value_counts()
        if counts.size > top_n:
            vals = counts.index[:top_n].tolist() + ['Other']
        else:
            vals = counts.index.tolist()
        rows.append({
            'Feature': feature_label,
            'Type': 'Categorical',
            'Min': '',
            'Max': '',
            'Mean': '',
            'Std': '',
            'Values': ", ".join(map(str, vals))
        })

summary_df = pd.DataFrame(rows)[['Feature', 'Type', 'Min', 'Max', 'Mean', 'Std', 'Values']]

# Reset index to start at 1
summary_df.index = range(1, len(summary_df) + 1)
summary_df
## for appendix
# Out:
#                     Feature         Type    Min     Max     Mean      Std  \
# 1                        id   Continuous      1   11001  5501.26  3175.71
# 2                      name  Categorical
# 3                     first  Categorical
# 4                      last  Categorical
# 5     compas_screening_date  Categorical
# 6                       sex  Categorical
# 7                       dob  Categorical
# 8                       age   Continuous     18      96    34.82    11.89
# 9                   age_cat  Categorical
# 10                     race  Categorical
# 11            juv_fel_count   Continuous      0      20     0.07     0.47
# 12             decile_score   Continuous      1      10     4.51     2.86
# 13           juv_misd_count   Continuous      0      13     0.09     0.49
# 14          juv_other_count   Continuous      0      17     0.11      0.5
# 15             priors_count   Continuous      0      38     3.47     4.88
# 16  days_b_screening_arrest   Continuous -414.0  1057.0      3.3    75.81
# 17                c_jail_in  Categorical
# 18               c_jail_out  Categorical
# 19            c_case_number  Categorical
# 20           c_offense_date  Categorical
# 21            c_arrest_date  Categorical
# 22       c_days_from_compas   Continuous    0.0  9485.0    57.73   329.74
# 23          c_charge_degree  Categorical
# 24            c_charge_desc  Categorical
# 25                 is_recid   Continuous      0       1     0.48      0.5
# 26            r_case_number  Categorical
# 27          r_charge_degree  Categorical
# 28       r_days_from_arrest   Continuous   -1.0   993.0    20.27    74.87
# 29           r_offense_date  Categorical
# 30            r_charge_desc  Categorical
# 31                r_jail_in  Categorical
# 32               r_jail_out  Categorical
# 33            violent_recid   Continuous    NaN     NaN      NaN      NaN
# 34         is_violent_recid   Continuous      0       1     0.11     0.32
# 35           vr_case_number  Categorical
# 36         vr_charge_degree  Categorical
# 37          vr_offense_date  Categorical
# 38           vr_charge_desc  Categorical
# 39       type_of_assessment  Categorical
# 40           decile_score.1   Continuous      1      10     4.51     2.86
# 41               score_text  Categorical
# 42           screening_date  Categorical
# 43     v_type_of_assessment  Categorical
# 44           v_decile_score   Continuous      1      10     3.69     2.51
# 45             v_score_text  Categorical
# 46         v_screening_date  Categorical
# 47               in_custody  Categorical
# 48              out_custody  Categorical
# 49           priors_count.1   Continuous      0      38     3.47     4.88
# 50                    start   Continuous      0     937    11.47    46.95
# 51                      end   Continuous      0    1186   553.44   399.02
# 52                    event   Continuous      0       1     0.38     0.49
# 53   Target: two_year_recid   Continuous      0       1     0.45      0.5
#
#                                                                                                                                         Values
# 1
# 2                                                    anthony smith, christopher hamilton, carlos vasquez, leroy battie, roderick thomas, Other
# 3                                                                                          michael, christopher, james, anthony, robert, Other
# 4                                                                                                williams, johnson, brown, smith, jones, Other
# 5                                                                            2013-02-20, 2013-03-20, 2013-02-07, 2013-04-20, 2013-01-03, Other
# 6                                                                                                                                 Male, Female
# 7                                                                            1987-12-21, 1990-02-22, 1990-05-02, 1994-07-15, 1989-04-27, Other
# 8
# 9                                                                                                       25 - 45, Greater than 45, Less than 25
# 10                                                                                  African-American, Caucasian, Hispanic, Other, Asian, Other
# 11
# 12
# 13
# 14
# 15
# 16
# 17                              2013-08-13 06:03:42, 2013-06-27 04:22:40, 2013-09-03 03:06:24, 2013-07-03 07:12:06, 2013-12-24 03:45:52, Other
# 18                              2013-09-12 10:31:00, 2013-09-14 05:58:00, 2013-09-28 02:10:00, 2013-09-23 08:25:00, 2013-12-10 10:30:00, Other
# 19                                                            13011352CF10A, 10014332CF10A, 13023525MM10A, 14006900CF10A, 14011664MM10A, Other
# 20                                                                           2013-01-14, 2013-02-22, 2013-03-01, 2013-04-07, 2013-02-16, Other
# 21                                                                           2013-02-06, 2013-03-22, 2013-05-15, 2013-03-21, 2013-10-22, Other
# 22
# 23                                                                                                                                        F, M
# 24                  Battery, arrest case no charge, Possession of Cocaine, Grand Theft in the 3rd Degree, Driving While License Revoked, Other
# 25
# 26                                                            13009779CF10A, 15000565MM30A, 13007620MM10A, 14012666TC10A, 13024813TC10A, Other
# 27                                                                                                         (M1), (M2), (F3), (F2), (F1), Other
# 28
# 29                                                                           2014-12-08, 2015-01-28, 2015-02-10, 2015-03-11, 2014-09-15, Other
# 30     Driving License Suspended, Possess Cannabis/20 Grams Or Less, Resist/Obstruct W/O Violence, Battery, Operating W/O Valid License, Other
# 31                                                                           2014-05-27, 2014-10-17, 2013-11-22, 2014-07-10, 2015-03-03, Other
# 32                                                                           2015-05-15, 2014-02-18, 2014-12-09, 2014-08-27, 2014-07-11, Other
# 33
# 34
# 35                                                            13009779CF10A, 13009112CF10A, 15013304CF10A, 15007310MM10A, 14003842CF10A, Other
# 36                                                                                                         (M1), (F3), (F2), (F1), (M2), Other
# 37                                                                           2015-08-15, 2015-09-04, 2015-03-29, 2014-12-26, 2015-06-26, Other
# 38  Battery, Felony Battery (Dom Strang), Battery on Law Enforc Officer, Aggravated Assault W/Dead Weap, Aggrav Battery w/Deadly Weapon, Other
# 39                                                                                                                          Risk of Recidivism
# 40
# 41                                                                                                                           Low, Medium, High
# 42                                                                           2013-02-20, 2013-03-20, 2013-02-07, 2013-04-20, 2013-01-03, Other
# 43                                                                                                                            Risk of Violence
# 44
# 45                                                                                                                           Low, Medium, High
# 46                                                                           2013-02-20, 2013-03-20, 2013-02-07, 2013-04-20, 2013-01-03, Other
# 47                                                                           2014-01-04, 2013-02-22, 2014-01-22, 2013-12-12, 2014-01-10, Other
# 48                                                                           2020-01-01, 2013-05-14, 2014-02-04, 2013-11-26, 2013-12-16, Other
# 49
# 50
# 51
# 52
# 53

# %%
# List of features actually used in the experiment 
cols_used = [
    'age', 'race', 'juv_fel_count', 'juv_misd_count',
    'juv_other_count', 'priors_count', 'sex=Male',
    'c_charge_degree=M', 'c_charge_desc=Alcohol_dui',
    'c_charge_desc=Drug', 'c_charge_desc=Property',
    'c_charge_desc=Violent', 'c_charge_desc=Weapons',
    'Target: two_year_recid'
]

filtered_df = summary_df[summary_df['Feature'].isin(cols_used)].copy()
filtered_df.index = range(1, len(filtered_df) + 1)
filtered_df
## for paper
# Out:
#                   Feature         Type Min Max   Mean    Std  \
# 1                     age   Continuous  18  96  34.82  11.89
# 2                    race  Categorical
# 3           juv_fel_count   Continuous   0  20   0.07   0.47
# 4          juv_misd_count   Continuous   0  13   0.09   0.49
# 5         juv_other_count   Continuous   0  17   0.11    0.5
# 6            priors_count   Continuous   0  38   3.47   4.88
# 7  Target: two_year_recid   Continuous   0   1   0.45    0.5
#
#                                                        Values
# 1
# 2  African-American, Caucasian, Hispanic, Other, Asian, Other
# 3
# 4
# 5
# 6
# 7

# %%
# Meta info 
n_instances   = len(df)
n_features    = df.shape[1] - 1  
positive_rate = df['two_year_recid'].mean() * 100

meta = pd.DataFrame({
    'Instances':          [n_instances],
    'Features':           [n_features],
    'Positive-class (%)': [round(positive_rate,1)]
})
display(meta)


# 1) Race counts & percentages
race_summary = pd.DataFrame({
    'Count':          df['race'].value_counts(),
    'Percentage (%)': df['race'].value_counts(normalize=True).mul(100).round(1)
})
race_summary = race_summary.sort_index()
display(race_summary)


# 2) Positive-class rate by sex
sex_rates = (
    df
    .groupby('sex')['two_year_recid']
    .mean()
    .mul(100)
    .round(1)
)
sex_rates = sex_rates.sort_index()
sex_rates_df = sex_rates.to_frame('Positive-class (%)')
display(sex_rates_df)


# 3) Positive-class rate by race
race_rates = (
    df
    .groupby('race')['two_year_recid']
    .mean()
    .mul(100)
    .round(1)
)
race_rates = race_rates.sort_index()
race_rates_df = race_rates.to_frame('Positive-class (%)')
display(race_rates_df)


# 4) Positive-class rate by race_group (Caucasian vs. Non-Caucasian)
df['race_group'] = np.where(df['race'] == 'Caucasian', 'Caucasian', 'Non-Caucasian')
racegrp_rates = (
    df
    .groupby('race_group')['two_year_recid']
    .mean()
    .mul(100)
    .round(1)
)
racegrp_rates = racegrp_rates.sort_index()
racegrp_rates_df = racegrp_rates.to_frame('Positive-class (%)')
display(racegrp_rates_df)


# 5) Intersectional 2×2 matrix
matrix = (
    df
    .assign(recid=df['two_year_recid'])
    .pivot_table(
        index='race_group',
        columns='sex',
        values='recid',
        aggfunc='mean'
    )
    .mul(100)
    .round(1)
)
matrix = matrix.sort_index().sort_index(axis=1)
matrix.index.name   = 'Race Group'
matrix.columns.name = 'Sex'
display(matrix)
# Out:
#    Instances  Features  Positive-class (%)
# 0       7214        52                45.1
#                   Count  Percentage (%)
# race
# African-American   3696            51.2
# Asian                32             0.4
# Caucasian          2454            34.0
# Hispanic            637             8.8
# Native American      18             0.2
# Other               377             5.2
#         Positive-class (%)
# sex
# Female                35.7
# Male                  47.3
#                   Positive-class (%)
# race
# African-American                51.4
# Asian                           28.1
# Caucasian                       39.4
# Hispanic                        36.4
# Native American                 55.6
# Other                           35.3
#                Positive-class (%)
# race_group
# Caucasian                    39.4
# Non-Caucasian                48.0
# Sex            Female  Male
# Race Group
# Caucasian        35.1  40.6
# Non-Caucasian    36.1  50.5
